# %% [markdown]
# #### Building Simple RNN

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
import numpy as np

# Create simple sine wave dataset
def create_sine_wave_dataset(seq_length=100):
    x = np.linspace(0, 50, seq_length)
    y = np.sin(x)
    return y

data = create_sine_wave_dataset()
time_steps = np.arange(len(data))

# Prepare dataset
def prepare_data(data, time_step, time_window):
    X, Y = [], []
    for i in range(len(data) - time_window):
        X.append(data[i:i + time_window])
        Y.append(data[i + time_window])
    return np.array(X), np.array(Y)
time_window = 10
X, Y = prepare_data(data, time_steps, time_window)

# Reshape the data to match RNN input shape
X = X.reshape((X.shape[0], X.shape[1], 1))

# Build Rnn model
model = Sequential([
    SimpleRNN(50, activation="relu", input_shape = (time_window, 1)),
    Dense(1)
])

# Compile model
model.compile(optimizer = "adam",
              loss = "mse"
             )

# train model
model.fit(X, Y, epochs = 20, batch_size=16)

# Make predictions
predictions = model.predict(X)

# plot the result
import matplotlib.pyplot as plt

plt.plot(time_steps, data, label="True Data")
plt.plot(time_steps[time_window:], predictions, label="Predictions")
plt.xlabel("Time Steps")
plt.ylabel("Value")
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# C:\ProgramData\miniconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4003
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2248
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1131
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0273
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0109
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0107
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0318e-04
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7653e-04
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6992e-04
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5352e-04
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4716e-04
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0756e-04
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0131e-04
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.0903e-05
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1233e-05
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.4865e-05
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step

# %% [markdown]
# #### Building LSTM

# %%
from tensorflow.keras.layers import LSTM

#model 
lstm_model = Sequential([
    LSTM(50, activation="relu", input_shape=(time_window, 1)),
    Dense(1)
])

# compile
lstm_model.compile(optimizer="adam",
                   loss = "mse"
                  )

# train
lstm_model.fit(X, Y, epochs=20, batch_size = 16)

# prediction
lstm_predictions = lstm_model.predict(X)

# plot
plt.plot(time_steps, data, label="True Data")
plt.plot(time_steps[time_window:], predictions, label="LSTM Predictions")
plt.xlabel("Time Steps")
plt.ylabel("Value")
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5180
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4404
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4319
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4065
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3635
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2636
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1541
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0299
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0283
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0104
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0127
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7751e-04
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1729e-04
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9629e-04
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1219e-04
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7855e-04
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2844e-04
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001CB57FA2840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001CB57FA2840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step

# %% [markdown]
# ### Text Preprocessing

# %%
from tensorflow.keras.layers import TextVectorization

# sample text data
texts = [
    "Hello how are you getting on?",
    "I.m fine .Thank you",
    "How about you?",
    "I.m Good too"
]
# Define the TextVectorization layer to tokenize and pad the text sequences
vectorizer = TextVectorization(output_mode="int", max_tokens = 100, output_sequence_length=10)

# Adapt the vectorizer to the text data
vectorizer.adapt(texts)
# Vectorize the text data
text_vectorized = vectorizer(texts)
print("Vectorized text data: \n", text_vectorized.numpy())
# Out:
# Vectorized text data:
#  [[ 8  4 12  2 10  7  0  0  0  0]
#  [ 3 11  6  2  0  0  0  0  0  0]
#  [ 4 13  2  0  0  0  0  0  0  0]
#  [ 3  9  5  0  0  0  0  0  0  0]]
